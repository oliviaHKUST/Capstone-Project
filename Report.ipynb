# %% [markdown]
# # Report of Segmenting and Clustering Cities Project
# ---
# **Xu Qianyi**
#
# Data Scientist

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# **In thie project, we are going to examine what are the most similar city in the world for some famous cities in the world, for example, would New York be the most similar city to London, since they are both famous finacial cities.**
#
# **Also, we will finally cluster 20 famous cities in worlds into 5 classes, and analyze the features of each cluster.**

# %% [markdown]
# ## 2. Source of Data

# %% [markdown]
# First, we collect List of cities by GDP and by population from Internet, all data required for this project is saved in a csv file.
#
# You can find the link of the source of data from the links listed below:
#
# > [List of cities by GDP](https://en.wikipedia.org/wiki/List_of_cities_by_GDP)
#
# > ![img](https://raw.githubusercontent.com/oliviaHKUST/Capstone-Project/master/Cities_by_GDP.png)
#
# > [List of cities by population](https://www.worldatlas.com/citypops.htm)
#
# > ![img](https://raw.githubusercontent.com/oliviaHKUST/Capstone-Project/master/Cities_by_Population.png)

# %% [markdown]
# ## 2. Methodology

# %% [markdown]
# For city clustering, we will use KNN module as the clustering algorithm to classify the cities.
#
# At the very beginning, we need to decide how to describe the features for each city. For this part, we will leverage the API of Foursquare to get the categories types of all venues in each cities. Then, to analyze the features quantitatively, we use the frequencies of all categories to describe the feature of a city.
#
# After computing the feature dataframe for all cities. With knn library from sklearn package, we are able to do the cities clustering work.
#
# We choose consine distance as the metrics to compute the similarity between each two-cities pair, and find the most similar city for all cities.

# %% [markdown]
# ## 3. Results

# %% [markdown]
# ### Examine similarity matrix

# %% [markdown]
# Similarity matrix can be found in the matrix listed below.

# %%
import pandas as pd
sim_matrix = pd.read_csv('sim_matrix.csv', index_col=0)
sim_matrix
# Out:
#                   Beijing   Chicago     Dallas  Houston    London   \
# Beijing           1.000000  0.335841  0.346995  0.280185  0.440741
# Chicago           0.335841  1.000000  0.591727  0.491465  0.583646
# Dallas            0.346995  0.591727  1.000000  0.637698  0.516346
# Houston           0.280185  0.491465  0.637698  1.000000  0.379337
# London            0.440741  0.583646  0.516346  0.379337  1.000000
# Los Angeles       0.181007  0.453926  0.460086  0.441013  0.340425
# New York          0.243969  0.488558  0.355295  0.382124  0.446815
# Osaka             0.267581  0.246369  0.333441  0.221701  0.383746
# Paris             0.294181  0.258478  0.304897  0.265700  0.447341
# Rhine-Ruhr        0.096601  0.083356  0.073744  0.082973  0.134473
# San Francisco     0.231381  0.390950  0.489314  0.350842  0.347969
# Sao Paulo         0.155560  0.434749  0.340662  0.327292  0.442232
# Seoul             0.542747  0.313003  0.310289  0.245846  0.399596
# Shanghai          0.527140  0.394508  0.350514  0.257205  0.607814
# Shenzhen          0.534757  0.409542  0.484985  0.328512  0.497935
# Tokyo             0.373914  0.331169  0.365184  0.219620  0.400741
# Washington, D.C.  0.284104  0.422592  0.487772  0.330468  0.506690
#
#                   Los Angeles   New York      Osaka    Paris   Rhine-Ruhr   \
# Beijing               0.181007   0.243969  0.267581  0.294181     0.096601
# %%
sim_matrix = pd.read_csv('similarity.csv', index_col=0)
sim_matrix
# Out:
#                  most similar city
# Beijing                     Seoul
# Chicago                     Dallas
# Dallas                    Houston
# Houston                     Dallas
# London                   Shanghai
# Los Angeles              Sao Paulo
# New York            San Francisco
# Osaka                       Tokyo
# Paris                      London
# Rhine-Ruhr                Shenzhen
# San Francisco            New York
# Sao Paulo             Los Angeles
# Seoul                     Beijing
# Shanghai                  Shenzhen
# Shenzhen                 Shanghai
# Tokyo                        Osaka
# Washington, D.C.           London

# %% [markdown]
# ### Examine Clusters

# %% [markdown]
# Examine each cluster and determine the discriminating venue categories that distinguish each cluster.

# %% [markdown]
# #### Cluster 1

# %%
cities_merged.loc[cities_merged['Cluster Labels'] == 0, cities_merged.columns[[0] + list(range(8, cities_merged.shape[1]))]]
# Out:
#                 City  Cluster Labels 1st Most Common Venue  \
# 1          New York                0                  Park
# 2       Los Angeles                0        Ice Cream Shop
# 3            London                0                 Hotel
# 5           Chicago                0               Theater
# 6             Seoul                0     Korean Restaurant
# 10            Dallas               0           Coffee Shop
# 11  Washington, D.C.               0   Monument / Landmark
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 1     Italian Restaurant      Sushi Restaurant    Seafood Restaurant
# 2            Art Gallery      Sushi Restaurant           Coffee Shop
# 3                Theater     Indian Restaurant            Steakhouse
# 5                   Park                 Hotel    Seafood Restaurant
# 6                  Hotel         Historic Site                  Café
# 10                 Hotel                   Bar    Mexican Restaurant
# 11            Art Museum                 Hotel        History Museum
#
#    5th Most Common Venue    6th Most Common Venue 7th Most Common Venue  \
# 1                  Hotel              Pizza Place                Bakery
# 2                    Bar              Music Venue               Theater
# 3                  Plaza       Seafood Restaurant             Bookstore
# 5              Gastropub               Donut Shop                   Bar
# 6           Noodle House                   Palace   Japanese Restaurant
# 10          Burger Joint  New American Restaurant                  Park
# 11           Coffee Shop       Salon / Barbershop   American Restaurant
#
#    8th Most Common Venue 9th Most Common Venue   10th Most Common Venue
# 1              Bookstore          Gourmet Shop          Thai Restaurant
# 2              Bookstore    Italian Restaurant         Ramen Restaurant
# 3                   Park              Boutique              Pizza Place
# 5     Italian Restaurant            Steakhouse  New American Restaurant
# 6             Art Museum                  Park                    Plaza
# 10              Dive Bar          Cocktail Bar      Japanese Restaurant
# 11     Indian Restaurant               Theater           Science Museum

# %% [markdown]
# Keywords: Park, Restaurant

# %% [markdown]
# #### Cluster 2

# %%
cities_merged.loc[cities_merged['Cluster Labels'] == 1, cities_merged.columns[[0] + list(range(8, cities_merged.shape[1]))]]
# Out:
#      City  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0  Tokyo                1                 Hotel      Ramen Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0       Soba Restaurant           Coffee Shop   Japanese Restaurant
#
#        6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0  Japanese Curry Restaurant      Sushi Restaurant       Udon Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0   Tonkatsu Restaurant      Electronics Store

# %% [markdown]
# Keywords: Hotel, Restaurant

# %% [markdown]
# #### Cluster 3

# %%
cities_merged.loc[cities_merged['Cluster Labels'] == 2, cities_merged.columns[[0] + list(range(8, cities_merged.shape[1]))]]
# Out:
#          City  Cluster Labels      1st Most Common Venue  \
# 4      Paris                2          French Restaurant
# 7       Osaka               2  Japanese Curry Restaurant
# 8   Sao Paulo               2                    Theater
# 12   Houston                2      Vietnamese Restaurant
# 15   Beijing                2              Historic Site
# 16   Shenzhen               2                      Hotel
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 4                  Plaza          Cocktail Bar        Sandwich Place
# 7               Sake Bar      Ramen Restaurant                 Hotel
# 8        Cultural Center           Pizza Place  Brazilian Restaurant
# 12                  Park                   Bar           Pizza Place
# 15                 Hotel                  Park                Hostel
# 16           Coffee Shop                  Café    Chinese Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 4              Bookstore              Wine Bar            Art Museum
# 7                 Bakery           Coffee Shop   Japanese Restaurant
# 8              Bookstore    Italian Restaurant        Ice Cream Shop
# 12           Beer Garden          Cocktail Bar                 Hotel
# 15           Coffee Shop    Chinese Restaurant     Yunnan Restaurant
# 16         Shopping Mall             Nightclub     Electronics Store
#
#     8th Most Common Venue   9th Most Common Venue 10th Most Common Venue
# 4           Historic Site                   Hotel     Italian Restaurant
# 7   Kushikatsu Restaurant                     Bar              BBQ Joint
# 8              Art Museum                    Park                   Café
# 12     Mexican Restaurant        Baseball Stadium    American Restaurant
# 15                   Café  Peking Duck Restaurant          Shopping Mall
# 16                    Spa              Restaurant    Japanese Restaurant

# %% [markdown]
# Keywords: Restaurant, Hotel

# %% [markdown]
# #### Cluster 4

# %%
cities_merged.loc[cities_merged['Cluster Labels'] == 3, cities_merged.columns[[0] + list(range(8, cities_merged.shape[1]))]]
# Out:
#           City  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 9  Rhine-Ruhr                3           Supermarket             Drugstore
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 9  Fast Food Restaurant                  Café                Bakery
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 9        Hardware Store         Big Box Store      Doner Restaurant
#
#   9th Most Common Venue  10th Most Common Venue
# 9        Ice Cream Shop  Furniture / Home Store

# %% [markdown]
# Keywords: Store, Supermarket, Resturant

# %% [markdown]
# #### Cluster 5

# %%
cities_merged.loc[cities_merged['Cluster Labels'] == 4, cities_merged.columns[[0] + list(range(8, cities_merged.shape[1]))]]
# Out:
#               City  Cluster Labels 1st Most Common Venue  \
# 13  San Francisco                4           Coffee Shop
# 14       Shanghai                4                 Hotel
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 13         Grocery Store           Yoga Studio                Bakery
# 14             Hotel Bar                Lounge    Chinese Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 13           Pizza Place      Sushi Restaurant        Ice Cream Shop
# 14     French Restaurant        Scenic Lookout   Dumpling Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 13                  Park            Art Museum              Gastropub
# 14                  Café            Restaurant     Italian Restaurant

# %% [markdown]
# Keywords: Resturant, Coffe

# %% [markdown]
# ## 4. Discussion

# %% [markdown]
# We get the five clusterings and the similarity matrix for nearly twenty cities in the world, the feature for each cities is quantitalize besed on the frequencies of categories types gathered from Foursquare API. The result is somehow reasonable, for example, Okasa is the most similar city to Tokyo beacause they are both Japanese cities, San Francisco is the most similar city to New York because they are both American and technical cities.
#
# However, more features should be added to a city to get a diverse analysis from different perspectives and a more accurate result.

# %% [markdown]
# ## 5. Conclusion

# %% [markdown]
# In thie project, we are going to examine what are the most similar city in the world for some famous cities in the world, for example, would New York be the most similar city to London, since they are both famous finacial cities.
#
# Also, we will finally cluster 20 famous cities in worlds into 5 classes, and analyze the features of each cluster.
